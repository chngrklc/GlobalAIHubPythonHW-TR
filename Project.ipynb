# %%
#Takıldığım bölümlerde emredmr7, burhanok kullanıcılarının programlarından faydalandım.
#Özellikle bu projede emredmr7 kullanıcısının programından faydalandım.
#tüm emeği geçenlere teşekkürler.


rname = "ali"
rsname = "veli"
derslist = ["biyoloji", "fizik", "tarih", "matematik", "kimya"]
dersler = []
notlar = {}
hak = 3

while True:
    name = input("Adınız : ")
    surname = input("Soyadınız : ")
    if (rname == name) and (rsname == surname):
        print(f"Merhaba {name} {surname}\n")
        sdersno = int(input("Kaç Ders Alacaksınız? : "))
        if (sdersno >= 3) and (sdersno <= 5):
            print(f"\n Ders Listeniz = {derslist}\n")
            while sdersno > 0:
                inders = input("Almak İstediğiniz Dersi Yazın : ")
                if inders not in derslist:
                    print("Ders Bulunamadı. Tekrar Yazın: ")
                    sdersno += 1
                else:
                    if inders in dersler:
                        print("Bu Ders Zaten Seçili. Tekrar Yazın :")
                        continue
                    dersler.append(inders)
                    print("Eklenen Ders: ",inders)
                sdersno -= 1
            sinav = input("Not Girilecek Dersi Yazın :")
            print("-"*15)
            midterm = int(input("Vize Notu : "))
            final = int(input("Final Notu : "))
            proje = int(input("Proje Notu : "))

            notlar["midterm"] = midterm
            notlar["final"] = final
            notlar["proje"] = proje

            ortalama = (midterm*(30/100)) + (final*(50/100)) + (proje*(20/100))

            if ortalama >= 90:
                print(f"\n Ortalamanız {ortalama} Notunuz: AA")
            elif ortalama < 90 and ortalama >= 70:
                print(f"\n Ortalamanız {ortalama} Notunuz: BB")
            elif ortalama < 70 and ortalama >= 50:
                print(f"\n Ortalamanız {ortalama} Notunuz: CC")
            elif ortalama < 50 and ortalama >= 30:
                print(f"\n Ortalamanız {ortalama} Notunuz: DD")
            else:
                print(f"\n Ortalamanız {ortalama} Notunuz: FF")
            break
        else:
            print("En az 3 - En Fazla 5 Ders Seçebilirsiniz.")
            break
    
    elif  (rname != name) or (rename != surname) and hak != 0:
        print("Öğrenci Bilgisi Yanlış. Tekrar Deneyin")
        hak -= 1
        print(f"Kalan Hakkınız : {hak}\n")
        if hak == 0:
            print("Program Sonlandırılıyor. Daha Sonra Deneyin.")
            break
# Out:
# Adınız : ali
# Soyadınız : veli
# Merhaba ali veli
#
# Kaç Ders Alacaksınız? : 3
#
#  Ders Listeniz = ['biyoloji', 'fizik', 'tarih', 'matematik', 'kimya']
#
# Almak İstediğiniz Dersi Yazın : fizik
# Eklenen Ders:  fizik
# Almak İstediğiniz Dersi Yazın : tarih
# Eklenen Ders:  tarih
# Almak İstediğiniz Dersi Yazın : kimya
# Eklenen Ders:  kimya
# Not Girilecek Dersi Yazın :kimya
# ---------------
# Vize Notu : 50
# Final Notu : 80
# Proje Notu : 50
#
#  Ortalamanız 65.0 Notunuz: CC
